# %% [markdown]
# Create either a script, jupyter notebook, or R markdown file that performs a relevant operation(s) on a number of files (>4) "automatically". This should be in your class repo and should be written in a manner that when I clone the repo I can generate the output. For instance the files will need to be in the repo or the script will need to be able to pull them from a public url. Note absolute paths will not work.
#
# This script takes 16 Dereplicated FASTA files and uses find, xargs, and swarm to take those dereplicated files and cluster them according to similarity.

# %%
# !find ../Derep/NOSPsample*.fasta
# Out:
# ../Derep/NOSPsampleACACAC.fasta
# ../Derep/NOSPsampleACAGCA.fasta
# ../Derep/NOSPsampleACATGT.fasta
# ../Derep/NOSPsampleACGACG.fasta
# ../Derep/NOSPsampleATATCG.fasta
# ../Derep/NOSPsampleATCAGT.fasta
# ../Derep/NOSPsampleCGACGA.fasta
# ../Derep/NOSPsampleCTCGCA.fasta
# ../Derep/NOSPsampleGATGAC.fasta
# ../Derep/NOSPsampleGCGCTC.fasta
# ../Derep/NOSPsampleGTCTCT.fasta
# ../Derep/NOSPsampleTCGCAT.fasta
# ../Derep/NOSPsampleTCGTCA.fasta
# ../Derep/NOSPsampleTGTATG.fasta
# ../Derep/NOSPsampleunkown.fasta

# %%
# !find ../Derep/NOSPsample*.fasta \
| xargs basename -s .fasta | xargs -I{} \
swarm \
-o ../Issue55/{}.txt \
-z \
../Derep/{}.fasta
# Out:
# Swarm 2.2.2 [Aug 27 2018 10:08:08]
# Copyright (C) 2012-2017 Torbjorn Rognes and Frederic Mahe
# https://github.com/torognes/swarm
#
# Mahe F, Rognes T, Quince C, de Vargas C, Dunthorn M (2014)
# Swarm: robust and fast clustering method for amplicon-based studies
# PeerJ 2:e593 https://doi.org/10.7717/peerj.593
#
# Mahe F, Rognes T, Quince C, de Vargas C, Dunthorn M (2015)
# Swarm v2: highly-scalable and high-resolution amplicon clustering
# PeerJ 3:e1420 https://doi.org/10.7717/peerj.1420
#
# CPU features:      mmx sse sse2 sse3 ssse3 sse4.1 sse4.2 popcnt avx
# Database file:     ../Derep/NOSPsampleACACAC.fasta
# Output file:       ../Issue55/NOSPsampleACACAC.txt
# Resolution (d):    1
# Threads:           1
# Break OTUs:        Yes
# Fastidious:        No
#
# Reading database:  100%
# Indexing database: 100%
# Database info:     1501897 nt in 4332 sequences, longest 351 nt
# Hashing sequences: 100%
# Clustering:        100%
# Writing swarms:    100%
#
# Number of swarms:  583
# ...
