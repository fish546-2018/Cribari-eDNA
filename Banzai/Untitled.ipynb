# %%
# !git clone https://github.com/jimmyodonnell/banzai.git
# Out:
# xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun

# %% [markdown]
# Use the git desktop to clone the pipeline into /users/kellycri/banzai-master

# %% [markdown]
# Run the test dataset of the pipeline to check everything is working ok

# %%
# !bash /Users/kellycribari/banzai-master/banzai.sh test
# Out:
# 	  🏄   ¡ BANZAI !
#
#
# Reading analysis parameters from:
# /Users/kellycribari/banzai-master/banzai_params.sh
#
# Reading sequencing metadata from:
# /Users/kellycribari/banzai-master/data/PS_16S/metadata.csv
#
# The file passes test for CRLF. Everybody dance!
#
# Checking for dependencies: pear cutadapt vsearch swarm seqtk python blastn R
# Found program pear in /usr/local/bin/pear
# Found program cutadapt in /usr/local/bin/cutadapt
# Found program vsearch in /usr/local/bin/vsearch
# Found program swarm in /usr/local/bin/swarm
# Found program seqtk in /usr/local/bin/seqtk
# Found program python in /Users/kellycribari/anaconda3/bin/python
# Found program blastn in /usr/local/ncbi/blast/bin/blastn
# Found program R in /usr/local/bin/R
# pigz installation not found; using gzip
#
# 4 cores detected.
#
# 2018-11-02 11:06 Analysis started at 20181102_1106
# Output is located in:
# /Users/kellycribari/banzai_out_20181102_1106
#
# Metadata has 280 rows and 16 columns including header.
# ...
